# %% [markdown]
# <a href="https://colab.research.google.com/github/amapuyan/Colab-exploration_sqlite3_pandas/blob/main/exploration_sqlite3_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sqlalchemy import create_engine
import seaborn as sns
import matplotlib.pyplot as plt
import sqlite3

# %%
# !pip freeze > packages.text

# %%
## Data source
# https://opendata.maryland.gov/Budget/County-Expenditures-By-Category-Fiscal-Year-2010/hh3e-irvk/about_data

data = pd.read_csv('https://opendata.maryland.gov/resource/hh3e-irvk.csv')
data
# Out:
#               county  general_government  public_safety  public_works  \
# 0           Allegany                 3.1            6.8          12.2
# 1       Anne Arundel                 5.4           12.2          11.6
# 2     Baltimore City                 5.7           14.3          16.7
# 3   Baltimore County                 4.8           11.8          11.7
# 4            Calvert                 4.0            7.3           8.1
# 5           Caroline                 3.0            7.7           2.8
# 6            Carroll                 6.2            5.4           6.5
# 7              Cecil                 3.9            9.0           7.0
# 8            Charles                 6.4           13.1           7.7
# 9         Dorchester                10.4            8.7           7.0
# 10         Frederick                 4.4           10.2           8.5
# 11           Garrett                 4.4            6.3          19.0
# 12           Harford                 9.6            9.6           9.1
# 13            Howard                 6.9           10.5           8.7
# 14              Kent                 6.8           11.8           9.0
# 15        Montgomery                 6.1           10.6          13.1
# 16   Prince George’s                 5.4            9.6          10.6
# 17      Queen Anne’s                 5.2           10.9           9.2
# 18        St. Mary’s                 5.7            9.0           7.1
# 19          Somerset                 8.3            7.3          10.2
# 20            Talbot                 6.7            9.3           7.9
# 21        Washington                 3.3            8.4           9.9
# 22          Wicomico                 2.5            7.2           4.8
# 23         Worcester                 6.7           12.4           8.9
# 24         Statewide                 5.7           10.8          11.5
#
#     health_social_services  education_libraries  parks_recreation  \
# 0                      6.2                 66.5               0.2
# 1                      3.5                 59.8               1.8
# 2                      4.8                 40.6               1.5
# 3                      2.5                 57.1               1.6
# 4                      3.1                 61.4               4.1
# 5                      4.3                 68.1               1.3
# 6                      3.3                 64.8               0.7
# 7                      4.0                 68.6               0.5
# 8                      3.1                 60.4               1.8
# 9                      4.6                 59.8               0.9
# 10                     4.6                 63.2               1.0
# 11                     5.0                 55.1               0.2
# 12                     2.7                 57.9               1.9
# 13                     2.4                 60.4               2.5
# 14                     9.5                 50.1               6.7
# 15                     4.8                 50.2               3.3
# 16                     2.2                 52.7               5.6
# 17                     5.1                 51.8               2.9
# 18                     3.5                 63.4               2.3
# 19                     6.2                 60.2               1.8
# 20                     6.1                 60.4               3.9
# 21                     3.1                 69.3               0.9
# 22                     7.0                 69.4               2.5
# 23                     6.6                 51.6               0.8
# 24                     3.7                 54.5               2.6
#
#     debt_service  other
# 0            2.6    2.3
# 1            4.7    1.1
# 2            2.9   13.5
# 3            3.0    7.4
# 4            5.5    6.5
# 5            6.6    6.2
# 6            6.6    6.6
# 7            4.8    2.2
# 8            5.4    2.2
# 9            2.4    6.2
# 10           4.7    3.4
# 11           1.5    8.5
# 12           6.4    2.7
# 13           6.2    2.4
# 14           3.8    2.4
# 15           5.0    6.9
# 16           4.1    9.8
# 17           4.3   10.7
# 18           3.3    5.6
# 19           4.4    1.6
# 20           0.7    5.0
# 21           3.1    2.0
# 22           3.5    3.1
# 23           4.6    8.4
# 24           4.3    6.9

# %%
## create blank sqlite db with name maryland2010.db

sqlite3.connect('maryland2010_fiscal.db')

# %%
## using sqlalchemy's create engine, create var conn to connect to our maryland2010_fiscal.db

conn = create_engine('sqlite:///maryland2010_fiscal.db')
conn
# Out:
# Engine(sqlite:///maryland2010_fiscal.db)

# %%
data.to_sql('fiscal2010', conn, if_exists='replace', index=False)
# Out:
# 25

# %%
sql_query1 = "select * from fiscal2010 where county like 'Hartford';"

resonse = pd.read_sql_query(sql_query1, conn)
resonse
# Out:
# Empty DataFrame
# Columns: [county, general_government, public_safety, public_works, health_social_services, education_libraries, parks_recreation, debt_service, other]
# Index: []
